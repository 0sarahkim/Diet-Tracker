# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv('C:/Users/Sarah/Desktop/Advanced Python/nutrition.csv',index_col=None,skip_blank_lines=True)

# %%
d=d[['name','serving_size','calories','protein','carbohydrate','total_fat','fiber','sugars']]

# %%
d
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories  protein carbohydrate total_fat  fiber   sugars
# 0          381   0.26 g      91.27 g      0.1g  0.9 g   0.00 g
# ...

# %%
def enter(name, serving_size):
    if name in food_list:
        #calculating the nutritional values
        kcal += int(kcal)
        protein += int(protein)
        carb += int(carb)
        fat += int(fat)
        sugar += int(sugar)
        outcome = "Your product provided you with %d kcal, "\
           "%d protein, %d carbs, %d of sugar and %d fat."\
    else:
        "print(Nutritional Information Unavailable")
    return outcome
# Out:
#   File "C:\Users\Sarah\AppData\Local\Temp/ipykernel_17704/4221541113.py", line 11
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
class Category(self):
    options=[
        ('breakfast','breakfast'),
        ('lunch','lunch'),
        ('dinner','dinner'),
        ('snacks','snacks'),
    ]
    name=models.CharField(max_length=50,choices=options)
    def __str__(self):
        return self.name

# %%
class Diet:
    def __init__(self):  
        self.dietlog = {}
    
    def print_menu(self, user):
        print("User:", user)
        
        print("1. Enter Weight")
        print("2. See Weight Trend")
        print("3. Calculate Calories")
        print("4. See Nutritional Info")
        
        menu = int(input("Choose Action: "))
        if menu == 1:
            print(self.dietlog[user]['WeightEntry'])
        elif menu == 2:
            print(self.dietlog[user]['WeightTrend'])
        elif menu == 3:
            print(self.dietlog[user]['CalculateCalories'])
        else:    
            print(self.dietlog[user]['Nutrition'])
    
    def run(self, user, menu):
        now = datetime.now()
        timestamp = now.strftime("%m/%d/%Y, %H:%M:%S")
        
        setattr(content, "timestamp", timestamp)
        
        if user not in self.playlist.keys():
            self.playlist[user] = {}
            self.playlist[user]['Movie'] = []
            self.playlist[user]['Song'] = []
            self.playlist[user]['Podcast'] = []
            
            if type(content).__name__ == 'Song':
                self.playlist[user]['Song'] = [content]
                print('Add Song')
                
            elif type(content).__name__ == 'Movie':
                self.playlist[user]['Movie'] = [content]
                print('Add Movie')
                
            elif type(content).__name__ == 'Podcast':
                self.playlist[user]['Podcast'] = [content]
                print('Add Podcast')
        else:
            if type(content).__name__ == 'Song':
                self.playlist[user]['Song'].append(content)
                print('Add Song')
                print(self.playlist[user]['Song'])
            elif type(content).__name__ == 'Movie':
                self.playlist[user]['Movie'].append(content)
                print('Add Movie')
            elif type(content).__name__ == 'Podcast':
                self.playlist[user]['Podcast'].append(content)
                print('Add Podcast')

# %%
class Weight: 
    def __init__(self, title, artist, album, timestamp=None):
        self.title = title
        self.artist = artist
        self.album = album
        self.timestamp = timestamp
    
    def __str__(self):
        return f'Song: ({self.title} - {self.artist} / {self.album})' f'Played on: {self.timestamp}'
    
    def __repr__(self):
        return (f'<Song(title="{self.title}", artist="{self.artist}", album="{self.album}",timestamp="{self.timestamp}")>')

# %%
def main():
    try:
        current_weight = float(input('enter your current weight: '))
        target_weight = float(input('enter your target weight: '))
    except ValueError as error:
        print "please enter a numeric value"
        return 
    
    calc_weight(current_weight, target_weight)
    
def calc_weight(v, w, x, y):
    days_required = (v - w) * CALORIES_PER_POUND / y
    months_required = (days_required / 30)
    remaining_days = (days_required - x)
    remaining_months = (remaining_days / 30)
    pounds_remaining = ((v - w) - (y * x) / CALORIES_PER_POUND)
    pounds_burned = ((v - w) - pounds_remaining)
    
    print 'days required: ', days_required, 'months required: ', months_required, 'remaining days: ', remaining_days 
    print 'months remaining: ', remaining_months, 'pounds burned: ', pounds_burned, 'pounds remaining: ', pounds_remaining
    
    
main()
